# %% [markdown]
# <a href="https://colab.research.google.com/github/tejashwinirk/Agentic-AI/blob/main/agentic_ai_Lab6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip uninstall -y pyautogen autogen-agentchat autogen-core autogen-ext -q
# !pip install pyautogen==0.2.35 -q
# Out:
# WARNING: Skipping autogen-agentchat as it is not installed.
# WARNING: Skipping autogen-core as it is not installed.
# WARNING: Skipping autogen-ext as it is not installed.

# %%
# !pip install pyautogen

# %%
import autogen

print("AutoGen version:", autogen.__version__)
print("AutoGen imported successfully!")
# Out:
# AutoGen version: 0.2.35
# AutoGen imported successfully!
# /usr/local/lib/python3.12/dist-packages/google/colab/_import_hooks/_hook_injector.py:55: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   loader.exec_module(module)

# %%
import os
from getpass import getpass

os.environ["GROQ_API_KEY"] = getpass("Enter your Groq API key:")
# Out:
# Enter your Groq API key:··········

# %%
import os

GROQ_API_KEY = os.getenv("GROQ_API_KEY")

config_list = [
    {
        "model": "llama-3.1-8b-instant",
        "api_key": GROQ_API_KEY,
        "base_url": "https://api.groq.com/openai/v1"
    }
]

llm_config = {
    "config_list": config_list,
    "temperature": 0.4
}

print("Model configuration completed!")
# Out:
# Model configuration completed!

# %%
import autogen

writer = autogen.AssistantAgent(
    name="Writer",
    system_message=(
        "You are a professional blog writer. "
        "Write short, clear and engaging blog posts. "
        "When the Critic gives feedback, rewrite the blog post "
        "to improve it. "
        "Do not explain the changes; provide the revised blog post."
    ),
    llm_config=llm_config,
    human_input_mode="NEVER"
)

critic = autogen.AssistantAgent(
    name="Critic",
    system_message=(
        "You are a strict but helpful blog editor. "
        "Review the Writer's blog post. "
        "Give 2-3 specific improvements. "
        "If the blog post is already good, reply with APPROVED."
    ),
    llm_config=llm_config,
    human_input_mode="NEVER"
)

print("Writer and Critic agents created successfully!")
# Out:
# Writer and Critic agents created successfully!

# %%
result = critic.initiate_chat(
    writer,
    message="Write a 150-word blog post about the benefits of reading.",
    max_turns=4
)
# Out:
# Critic (to Writer):
#
# Write a 150-word blog post about the benefits of reading.
#
# --------------------------------------------------------------------------------
# [autogen.oai.client: 08-14 11:57:48] {329} WARNING - Model llama-3.1-8b-instant is not found. The cost will be 0. In your config_list, add field {"price" : [prompt_price_per_1k, completion_token_price_per_1k]} for customized pricing.
# WARNING:autogen.oai.client:Model llama-3.1-8b-instant is not found. The cost will be 0. In your config_list, add field {"price" : [prompt_price_per_1k, completion_token_price_per_1k]} for customized pricing.
# Writer (to Critic):
#
# **The Power of Reading: Unlocking a World of Benefits**
#
# ...

# %%
print("FINAL RESULT")
print("=" * 50)
print(result.summary)
# Out:
# FINAL RESULT
# ...
# **The Power of Reading: Unlocking a World of Benefits**
#
# Did you know that reading can be a powerful tool for personal growth and transformation? From reducing stress and anxiety to improving mental health and relationships, the benefits of reading are numerous and well-documented.
#
# For example, I recall a friend who struggled with anxiety and depression. Through reading self-help books and memoirs, she gained a deeper understanding of her emotions and developed coping strategies to manage her mental health. Her newfound knowledge and confidence transformed her life, allowing her to pursue her passions and build stronger relationships.
#
# Reading can improve your vocabulary, memory, and concentration, making you a more effective learner and problem-solver. It can also expand your knowledge, broaden your perspectives, and foster empathy and understanding.
#
# ...
