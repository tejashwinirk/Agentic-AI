# %% [markdown]
# <a href="https://colab.research.google.com/github/tejashwinirk/Agentic-AI/blob/main/Copy_of_Lab9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain langchain-groq langsmith -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 1.4 MB/s eta 0:00:00

# %%
import os

os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_API_KEY"] = "API_KEY"
os.environ["LANGCHAIN_PROJECT"] = "Lab9-Agentic-AI"

print("LangSmith tracing enabled!")
# Out:
# LangSmith tracing enabled!

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    api_key="ENTER_API_KEY",
    model="llama-3.1-8b-instant",
    temperature=0
)

print("Groq model connected!")
# Out:
# Groq model connected!

# %%
question = (
    "A shop sells pens at 12 rupees each. "
    "If I buy 7 and pay with 100, "
    "how much change do I receive? "
    "Give the calculation and final answer."
)

response = llm.invoke(question)

print(response.content)
# Out:
# To find the change, we need to calculate the total cost of the pens and subtract that from the amount paid.
#
# Cost of 1 pen = 12 rupees
# Cost of 7 pens = 7 * 12 = 84 rupees
#
# Amount paid = 100 rupees
#
# Change = Amount paid - Cost of 7 pens
# = 100 - 84
# = 16 rupees
#
# So, you will receive 16 rupees as change.
