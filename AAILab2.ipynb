# %% [markdown]
# <a href="https://colab.research.google.com/github/tejashwinirk/Agentic-AI/blob/main/AAILab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langgraph langchain-groq -q

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(api_key="gsk_APIkey",

               model="llama-3.1-8b-instant", temperature=0)

# %%
from typing import TypedDict, List



class ChatState(TypedDict):

    messages: List[str]     # the running conversation

    name: str               # remembered user name

    preferences: str        # remembered preferences

# %%
def chatbot(state: ChatState) -> dict:

    user_msg = state['messages'][-1]

    # very simple memory rules for a beginner demo

    name = state.get('name', '')

    prefs = state.get('preferences', '')
    if 'my name is' in user_msg.lower():

        name = user_msg.lower().split('my name is')[-1].strip().title()

    if 'i like' in user_msg.lower():

        prefs = user_msg.lower().split('i like')[-1].strip()

    context = f"The user's name is {name}. They like {prefs}."

    reply = llm.invoke(context + ' Reply to: ' + user_msg).content

    return {'messages': state['messages'] + [reply],

            'name': name, 'preferences': prefs}

# %%
from langgraph.graph import StateGraph, START, END



builder = StateGraph(ChatState)

builder.add_node('chatbot', chatbot)

builder.add_edge(START, 'chatbot')

builder.add_edge('chatbot', END)

graph = builder.compile()

# %%
state = {'messages': [], 'name': '', 'preferences': ''}



while True:

    user = input('You: ')

    if user.lower() == 'quit':

        break

    state['messages'].append(user)

    state = graph.invoke(state)

    print('Bot:', state['messages'][-1])
# Out:
# Bot: Hello Tejashwini, it's nice to meet you. What do you like?
# Bot: That's great to hear, . Reading is such a wonderful hobby. What kind of books do you enjoy reading the most? Are you into fiction, non-fiction, mystery, sci-fi, or something else?
# Bot: Hi there, . I see you enjoy reading fiction and fantasy. Those are two amazing genres that can transport you to new worlds and spark your imagination. Are you a fan of classic fantasy authors like J.R.R. Tolkien or C.S. Lewis, or do you prefer more modern authors like George R.R. Martin or Patrick Rothfuss?
# Bot: I'm happy to chat with you. Unfortunately, I don't know your name yet. You mentioned earlier that you like reading, but you didn't share your name with me. Would you like to tell me what your name is?
# Bot: Nice to meet you, Tejashwini. I've heard you're an avid reader. What kind of books do you enjoy reading the most?
# Bot: Nice to meet you, Tejashwini.
